# %% [markdown]
# # Pandas
# ----

# %%
import pandas as pd

# %%
pwd
# Out:
# '/home/vitor/Documents/lr-complete-guide-tensorflow-deep-learning/python-overview'

# %%
df = pd.read_csv('../files/salaries.csv')

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
df['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
df[['JobTitle', 'TotalPayBenefits']]
# Out:
#                                               JobTitle  TotalPayBenefits
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY         567595.43
# 1                      CAPTAIN III (POLICE DEPARTMENT)         538909.28
# 2                      CAPTAIN III (POLICE DEPARTMENT)         335279.91
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         332343.61
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)         326373.19
# ...                                                ...               ...
# 148649                                       Custodian              0.00
# 148650                                    Not provided              0.00
# 148651                                    Not provided              0.00
# 148652                                    Not provided              0.00
# 148653                      Counselor, Log Cabin Ranch           -618.13
#
# [148654 rows x 2 columns]

# %%
df['TotalPayBenefits'].max()
# Out:
# 567595.43

# %%
df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448841    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
myFilter = df['TotalPayBenefits'] == df['TotalPayBenefits'].max()
df[myFilter]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
df.as_matrix()
# Out:
# /home/vitor/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# array([[1, 'NATHANIEL FORD',
#         'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', ..., nan,
#         'San Francisco', nan],
#        [2, 'GARY JIMENEZ', 'CAPTAIN III (POLICE DEPARTMENT)', ..., nan,
#         'San Francisco', nan],
#        [3, 'ALBERT PARDINI', 'CAPTAIN III (POLICE DEPARTMENT)', ..., nan,
#         'San Francisco', nan],
#        ...,
#        [148652, 'Not provided', 'Not provided', ..., nan,
#         'San Francisco', nan],
#        [148653, 'Not provided', 'Not provided', ..., nan,
#         'San Francisco', nan],
#        [148654, 'Joe Lopez', 'Counselor, Log Cabin Ranch', ..., nan,
#         'San Francisco', nan]], dtype=object)

# %%
df.values
# Out:
# array([[1, 'NATHANIEL FORD',
#         'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', ..., nan,
#         'San Francisco', nan],
#        [2, 'GARY JIMENEZ', 'CAPTAIN III (POLICE DEPARTMENT)', ..., nan,
#         'San Francisco', nan],
#        [3, 'ALBERT PARDINI', 'CAPTAIN III (POLICE DEPARTMENT)', ..., nan,
#         'San Francisco', nan],
#        ...,
#        [148652, 'Not provided', 'Not provided', ..., nan,
#         'San Francisco', nan],
#        [148653, 'Not provided', 'Not provided', ..., nan,
#         'San Francisco', nan],
#        [148654, 'Joe Lopez', 'Counselor, Log Cabin Ranch', ..., nan,
#         'San Francisco', nan]], dtype=object)
